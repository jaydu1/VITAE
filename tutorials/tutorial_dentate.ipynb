# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import umap

import matplotlib.pyplot as plt
import matplotlib
 
import pickle as pk
import h5py

# If you use the code in Github's folder VITAE instead of installing 
# via PyPI, then you need to add parent folder path to load our package
import sys; sys.path.insert(0, '..')

# %% [markdown]
# # Load data

# %% [markdown]
# Our algorithm requires at least two inputs:
#
# - `count`$\in \mathbb{R}^{n_{\text{cell}}\ \ \times\ \ n_{\text{gene}}}$, the raw count matrix for the UMI/non-UMI model, or the preprocessed expression matrix for the Gaussian model.
# - `NUM_CLUSTER`$\in \mathbb{N}^+$, the number of clusters.
#
# One can also provides some prior information:
#
# - `grouping`$\in \mathbb{R}^{n_{\text{cell}}}$, the true/estimated groupings
# - `gene_names`$\in \mathbb{R}^{n_{\text{cell}}}$
# - `cell_ids`$\in \mathbb{R}^{n_{\text{cell}}}$
#
# We have prepare some datasets in **hdf5** format, which can be easily loaded by the following codes:

# %%
from VITAE import get_igraph, louvain_igraph, plot_clusters, load_data

file_name = 'dentate'
data = load_data(path='../data/',
                 file_name=file_name)

# To see the available fields of the dataset
print(data.keys())
# Out:
# dict_keys(['count', 'grouping', 'gene_names', 'cell_ids', 'milestone_network', 'root_milestone_id', 'type'])

# %% [markdown]
# Or we can directly use `scanpy` to load dataset and deal with `AnnData` object.

# %%
# Optional when scanpy is installed
import scanpy as sc
adata = sc.AnnData(data['count'])

# %% [markdown]
# # Preprocess data

# %% [markdown]
# We follows the precedure
#
# - Remove cells without expressions.
# - Remove genes without variations across samples.
# - Apply log-normalization to the count data $X$ and get $X_{\text{norm}}$.
# - Select influential genes based on $X$ by the method described in Page 12-13: Data preprocessing - Feature selection for individual datasets, https://www.biorxiv.org/content/biorxiv/early/2018/11/02/460147.full.pdf.
# - Apply per-gene standardization to $X_{\text{norm}}$ as the input of the neural network.

# %%
from VITAE import VITAE

# clear the tf session if necessary
tf.keras.backend.clear_session() 

# create an instance
model = VITAE()

# fit in data
model.get_data(X = data['count'],             # count or expression matrix, (dense or sparse) numpy array 
               labels = data['grouping'],     # (optional) labels, which will be converted to string
               covariate=None,                # (optional) covariates
               gene_names=data['gene_names'], # (optional) gene names, which will be converted to string
               cell_names=data['cell_ids']    # (optional) cell names, which will be converted to string
              )

# preprocess data
model.preprocess_data(K = 1e4,                # (optional) denominator of the scale factor for log-normalization (the default is 1e4)
                      gene_num = 2000,        # (optional) maximum number of influential genes to keep (the default is 2000)
                      data_type = 'Gaussian',      # (optional) data_type can be 'UMI', 'non-UMI' or 'Gaussian' (the default is 'UMI')
                      npc = 64                # (optional) number of PCs to keep if data_type='Gaussian' (the default is 64)
                     )
# Out:
# Removing 0 cells without expression.
# Removing 277 genes without variability.
# min normailized value: 0.0
# max normailized value: 8.149757
# Number of cells in each class:
# 0 <---> Granule-immature    1333
# 1 <---> Granule-mature      1712
# 2 <---> Neuroblast_1          97
# 3 <---> Neuroblast_2         777
# 4 <---> nIPC                  88
# dtype: int64

# %% [markdown]
# Or we can use `scanpy` to preprocess the data. Input `adata` to `get_data` function. This step uses Seurat processing as above.

# %%
# Optional when scanpy is installed
# create an instance
model = VITAE()

# fit in data
model.get_data(adata = adata,                 # AnnData scanpy object 
               labels = data['grouping'],     # (optional) labels, which will be converted to string
               covariate=None,                # (optional) covariates
               gene_names=data['gene_names'], # (optional) gene names, which will be converted to string
               cell_names=None                # (optional) cell names, which will be converted to string
              )

# preprocess data
model.preprocess_data(processed = False,      # (optional) User can specify whether the AnnData has been processed, if so, Gaussian is applied
                      dimred = False,         # (optional) If the AnnData has been processed, user can specify whether the AnnData has been through dimension reduction, if not, PCA is applied
                      K = 1e4,                # (optional) denominator of the scale factor for log-normalization (the default is 1e4)
                      gene_num = 2000,        # (optional) maximum number of influential genes to keep (the default is 2000)
                      data_type = 'UMI',      # (optional) data_type can be 'UMI', 'non-UMI' or 'Gaussian' (the default is 'UMI')
                      npc = 64                # (optional) number of PCs to keep if data_type='Gaussian' (the default is 64)
                     )

# %% [markdown]
# # Build model

# %% [markdown]
# Now we are able to create the neural network.

# %%
model.build_model(dim_latent = 8,         # The size of the latent dimension
                  dimensions=[16]         # The size of each layer in the encoder between the input layer and the 
                                          # latent layer. The size of each layer in the decoder is the reverse.
                  )

# %% [markdown]
# # Pretrain

# %% [markdown]
# In the current stage, we only define the Autoencoder. The latent sturcture is still undefined. Before adding that, we'd better pretrain the Autoencoder to learn a better reprsentation $Z$ of $X$.
#
# A large batch size will give a better and stable model, while it takes more memory to run. So if you are concerned about this, you could reduce the batch size.

# %%
model.pre_train(learning_rate = 1e-3,        # (Optional) the initial learning rate for the Adam optimizer (the default is 1e-3).
                batch_size=256,              # (Optional) the batch size for pre-training (the default is 32). 
                L=1,                         # (Optional) the number of MC samples (the default is 1).
                alpha=0.01,                  # (Optional) the value of alpha in [0,1] to encourage covariate adjustment. Not used if there is no covariates.
                num_epoch = 300,             # (Optional) the maximum number of epoches (the default is 300).                
                num_step_per_epoch = None,   # (Optional) the number of step per epoch, it will be inferred from number of cells and batch size if it is None (the default is None).
                early_stopping_tolerance=1,  # (Optional) the minimum change of loss to be considered as an improvement (the default is 1e-3).
                early_stopping_patience=5,   # (Optional) the maximum number of epoches if there is no improvement (the default is 10).
                early_stopping_warmup=0,     # (Optional) the number of warmup epoches (the default is 0).
                path_to_weights=None         # (Optional) the path of weight file to be saved; not saving weight if None (the default is None).
                )
# Out:
# Pretrain - Start of epoch 0
# 16/16 [==============================] - 2s 156ms/step - Reconstructed Loss: 192.4653
#  Training loss over epoch: 162.81057739257812
# Pretrain - Start of epoch 1
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 131.6448
#  Training loss over epoch: 155.72528076171875
# Pretrain - Start of epoch 2
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 171.6891
#  Training loss over epoch: 152.7207794189453
# Pretrain - Start of epoch 3
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 134.4131
#  Training loss over epoch: 149.75619506835938
# Pretrain - Start of epoch 4
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 184.9308
#  Training loss over epoch: 145.0167236328125
# Pretrain - Start of epoch 5
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 126.0303
#  Training loss over epoch: 144.20285034179688
# Pretrain - Start of epoch 6
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 172.7817
#  Training loss over epoch: 139.47312927246094
# Pretrain - Start of epoch 7
# 16/16 [==============================] - 0s 13ms/step - Reconstructed Loss: 130.9174
#  Training loss over epoch: 136.60848999023438
# Pretrain - Start of epoch 8
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 116.1242
#  Training loss over epoch: 132.51512145996094
# Pretrain - Start of epoch 9
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 139.6936
#  Training loss over epoch: 129.54286193847656
# Pretrain - Start of epoch 10
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 143.8713
#  Training loss over epoch: 127.23129272460938
# Pretrain - Start of epoch 11
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 122.0865
#  Training loss over epoch: 123.93083190917969
# Pretrain - Start of epoch 12
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 115.0585
#  Training loss over epoch: 122.05804443359375
# Pretrain - Start of epoch 13
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 102.4632
#  Training loss over epoch: 118.7599105834961
# Pretrain - Start of epoch 14
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 108.7181
#  Training loss over epoch: 117.03716278076172
# Pretrain - Start of epoch 15
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 116.4524
#  Training loss over epoch: 114.33323669433594
# Pretrain - Start of epoch 16
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 93.7497
#  Training loss over epoch: 111.6557388305664
# Pretrain - Start of epoch 17
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 137.6369
#  Training loss over epoch: 110.8875732421875
# Pretrain - Start of epoch 18
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 130.5031
#  Training loss over epoch: 109.01426696777344
# Pretrain - Start of epoch 19
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 103.7136
#  Training loss over epoch: 105.66253662109375
# Pretrain - Start of epoch 20
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 110.6302
#  Training loss over epoch: 103.66737365722656
# Pretrain - Start of epoch 21
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 122.6074
#  Training loss over epoch: 101.91956329345703
# Pretrain - Start of epoch 22
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 103.4976
#  Training loss over epoch: 100.02818298339844
# Pretrain - Start of epoch 23
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 116.9104
#  Training loss over epoch: 98.80670928955078
# Pretrain - Start of epoch 24
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 122.6599
#  Training loss over epoch: 97.02761840820312
# Pretrain - Start of epoch 25
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 109.9649
#  Training loss over epoch: 95.53315734863281
# Pretrain - Start of epoch 26
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 99.7452
#  Training loss over epoch: 94.46488189697266
# Pretrain - Start of epoch 27
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 80.9116
#  Training loss over epoch: 92.91082763671875
# Pretrain - Start of epoch 28
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 99.2317
#  Training loss over epoch: 91.18939971923828
# Pretrain - Start of epoch 29
# 16/16 [==============================] - 0s 13ms/step - Reconstructed Loss: 101.0546
#  Training loss over epoch: 89.82102966308594
# Pretrain - Start of epoch 30
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 83.9974
#  Training loss over epoch: 88.59886169433594
# Pretrain - Start of epoch 31
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 85.7991
#  Training loss over epoch: 87.35233306884766
# Pretrain - Start of epoch 32
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 78.7599
#  Training loss over epoch: 86.19981384277344
# Pretrain - Start of epoch 33
# 16/16 [==============================] - 0s 13ms/step - Reconstructed Loss: 96.2882
#  Training loss over epoch: 85.80773162841797
# Pretrain - Start of epoch 34
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 69.9839
#  Training loss over epoch: 85.3483657836914
# Pretrain - Start of epoch 35
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 76.5063
#  Training loss over epoch: 84.52359008789062
# Pretrain - Start of epoch 36
# 16/16 [==============================] - 0s 14ms/step - Reconstructed Loss: 74.4644
#  Training loss over epoch: 83.01950073242188
# Pretrain - Start of epoch 37
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 68.6979
#  Training loss over epoch: 82.40272521972656
# Pretrain - Start of epoch 38
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 82.6963
#  Training loss over epoch: 82.24671936035156
# Pretrain - Start of epoch 39
# 16/16 [==============================] - 0s 9ms/step - Reconstructed Loss: 73.6674
#  Training loss over epoch: 81.15621185302734
# Pretrain - Start of epoch 40
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 91.0743
#  Training loss over epoch: 82.2723159790039
# Pretrain - Start of epoch 41
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 106.4203
#  Training loss over epoch: 80.34619903564453
# Pretrain - Start of epoch 42
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 77.7145
#  Training loss over epoch: 80.74938201904297
# Pretrain - Start of epoch 43
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 68.0718
#  Training loss over epoch: 78.88550567626953
# Pretrain - Start of epoch 44
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 90.6251
#  Training loss over epoch: 79.68350219726562
# Pretrain - Start of epoch 45
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 84.5040
#  Training loss over epoch: 80.38423156738281
# Pretrain - Start of epoch 46
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 62.7568
#  Training loss over epoch: 78.18883514404297
# Pretrain - Start of epoch 47
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 87.8363
#  Training loss over epoch: 78.19341278076172
# Pretrain - Start of epoch 48
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 77.0174
#  Training loss over epoch: 77.14155578613281
# Pretrain - Start of epoch 49
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 84.7037
#  Training loss over epoch: 77.5162353515625
# Pretrain - Start of epoch 50
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 73.5528
#  Training loss over epoch: 76.57424926757812
# Pretrain - Start of epoch 51
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 64.5092
#  Training loss over epoch: 76.16128540039062
# Pretrain - Start of epoch 52
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 67.6197
#  Training loss over epoch: 75.49403381347656
# Pretrain - Start of epoch 53
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 76.9459
#  Training loss over epoch: 75.91533660888672
# Pretrain - Start of epoch 54
# 16/16 [==============================] - 0s 13ms/step - Reconstructed Loss: 73.0050
#  Training loss over epoch: 75.40423583984375
# Pretrain - Start of epoch 55
# 16/16 [==============================] - 0s 13ms/step - Reconstructed Loss: 89.4786
#  Training loss over epoch: 75.92154693603516
# Pretrain - Start of epoch 56
# 16/16 [==============================] - 0s 14ms/step - Reconstructed Loss: 60.5320
#  Training loss over epoch: 74.12020111083984
# Pretrain - Start of epoch 57
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 84.0117
#  Training loss over epoch: 73.88941955566406
# Pretrain - Start of epoch 58
# 16/16 [==============================] - 0s 9ms/step - Reconstructed Loss: 84.2473
#  Training loss over epoch: 74.6337890625
# Pretrain - Start of epoch 59
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 70.1018
#  Training loss over epoch: 73.83939361572266
# Pretrain - Start of epoch 60
# 16/16 [==============================] - 0s 12ms/step - Reconstructed Loss: 71.8741
#  Training loss over epoch: 73.78636169433594
# Pretrain - Start of epoch 61
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 79.7031
#  Training loss over epoch: 73.31426239013672
# Pretrain - Start of epoch 62
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 64.8759
#  Training loss over epoch: 72.6844253540039
# Pretrain - Start of epoch 63
# 16/16 [==============================] - 0s 9ms/step - Reconstructed Loss: 72.9586
#  Training loss over epoch: 71.93008422851562
# Pretrain - Start of epoch 64
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 62.4479
#  Training loss over epoch: 72.04632568359375
# Pretrain - Start of epoch 65
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 74.7951
#  Training loss over epoch: 72.03440856933594
# Pretrain - Start of epoch 66
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 75.1483
#  Training loss over epoch: 72.83826446533203
# Pretrain - Start of epoch 67
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 70.2889
#  Training loss over epoch: 71.22542572021484
# Pretrain - Start of epoch 68
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 74.8388
#  Training loss over epoch: 71.14280700683594
# Pretrain - Start of epoch 69
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 62.2835
#  Training loss over epoch: 70.45890045166016
# Pretrain - Start of epoch 70
# 16/16 [==============================] - 0s 11ms/step - Reconstructed Loss: 67.5575
#  Training loss over epoch: 71.43923950195312
# Pretrain - Start of epoch 71
# 16/16 [==============================] - 0s 9ms/step - Reconstructed Loss: 70.5933
#  Training loss over epoch: 70.47218322753906
# Pretrain - Start of epoch 72
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 77.0978
#  Training loss over epoch: 70.62017059326172
# Pretrain - Start of epoch 73
# 16/16 [==============================] - 0s 10ms/step - Reconstructed Loss: 97.2005
# Best Epoch: 67. Best Metric: 71.225426.
# Early stopping.
# Pretrain Done.

# %% [markdown]
# You can also save and load model weights by the following codes:

# %%
# save model weight
# model.save_model(path_to_file='weight/dentate_Gaussian_pretrain.checkpoint')

# load model weight, which can build or re-build the network based on wieght file 
model.load_model(path_to_file='weight/dentate_Gaussian_pretrain.checkpoint', # path to the weight file.
                 load_labels=False                 # (Optional) whether to load clustering labels or not.
                                                   # If load_labels is True, then the LatentSpace layer
                                                   # will be initialized basd on the model. 
                                                   # If load_labels is False, then the LatentSpace layer
                                                   # will not be initialized.
                )

# %% [markdown]
# # Clustering and initialize latent structure

# %% [markdown]
# If you have information of the grouping/labels of cells, you are free to use them to initialze the latent structure, so that you will get better estimate and inference results, especially when the sample size is small or the classes are unbalanced.

# %%
# Get latent representations of X after pre-training
z = model.get_latent_z()

# Assign pre-given labels to initialize the latent structure
# The object 'model.labels' is encoded as categorical data from 'model.label_names'.
labels = model.label_names

# %% [markdown]
# We can plot the clusters to see how it looks like. We provide a function to do dimension reduction easily.

# %%
from VITAE import get_embedding
embed_z = get_embedding(z, 
                        dimred='umap', # 'umap', pca' and 'tsne'. Recommend to use umap for general data
                                       # as it is fast. Sometimes 'umap' will break points into separate
                                       # clusters, in such case 'tsne' is recommended while it is somehow 
                                       # slow. For simple data, 'pca' will be good enough.
                       # **kwargs, extra key-value argument for the dimension reduction algorithms
                       )
     
plot_clusters(embed_z, labels)

# %% [markdown]
# Suppose we want to select a subset of the cells. For example, we want to remove cluster '09' (which is encoded as 4), we can do:
#
# ```
# cell_subsets = model.cell_names[labels != 'nIPC']
# model.set_cell_subset(cell_subsets)
# # this will update the model variables 'selected_cell_subset' & 'selected_cell_subset_id',
# # corresponding to cell names & cell ids respectively.
# # However, if you do not select a subset, these two variables will also be initialzed to
# # be include all cells.
# labels = labels[model.selected_cell_subset_id]
# z = z[model.selected_cell_subset_id,:]
# ```
#
# Then the later operations, such as training and inference, will automatically only deal with the selected subset of cells.

# %% [markdown]
# Now we need to determine $k$, either from prior information or clustering results. And we also need to initialze $\pi$ and $\mu$.
#
# - $\mu$: The user can provide $\mu$, the clustering centers. If not given, $\mu$ is initialized by the mean of each cluster corrsponding to the given clustering labels in latent space. If clustering labels are not given, $\mu$ is sampled from uniform $[-1,1]$.
# - $\pi$: The user can provide $\pi=(\pi_{1,1},\cdots,\pi_{1,k},\pi_{2,2},\cdots,\pi_{2,k},\cdots, \pi_{k,k})\in\mathbb{R}^{1\times K}$, the prior proportion for each node and each edge. If not given, $\pi$ is uniformly initialized.

# %%
NUM_CLUSTER = len(np.unique(labels))

model.init_latent_space(
    NUM_CLUSTER,                     # numebr of clusters
    cluster_labels=labels,           # (optional) clustering labels or their names for plotting
    mu=None,                         # (optional) initial mean
    log_pi=None                      # (optional) initial pi
               )

# %% [markdown]
# In case we don't have labels, we could do Louvain clustering by the following codes. You can choose different resolution parameter to get satisfactory clustering results.
#
# ```
# from scTGMVAE import get_igraph, louvain_igraph, plot_clusters
# z = model.get_latent_z()
# embed_z = umap.UMAP().fit_transform(z)
# g = get_igraph(z)
# labels = louvain_igraph(g, res = 0.6)
# plot_clusters(embed_z, labels)
# print(np.unique(labels))
# ```

# %% [markdown]
# And we can also use estimated cluster labels from other algorithms and softwares.

# %% [markdown]
# # Train

# %%
model.train(learning_rate = 1e-3,        # (Optional) the initial learning rate for the Adam optimizer (the default is 1e-3).
            batch_size=256,              # (Optional) the batch size for pre-training (the default is 32). 
            L=1,                         # (Optional) the number of MC samples (the default is 1).
            alpha=0.01,                  # (Optional) the value of alpha in [0,1] to encourage covariate adjustment. Not used if there is no covariates.
            beta=2,                      # (Optional) the value of beta in beta-VAE.
            num_epoch = 300,             # (Optional) the maximum number of epoches (the default is 300).                
            num_step_per_epoch = None,   # (Optional) the number of step per epoch, it will be inferred from number of cells and batch size if it is None (the default is None).
            early_stopping_tolerance=1,  # (Optional) the minimum change of loss to be considered as an improvement (the default is 1e-3).
            early_stopping_patience=5,   # (Optional) the maximum number of epoches if there is no improvement (the default is 10).
            early_stopping_warmup=5,     # (Optional) the number of warmup epoches (the default is 0).
            path_to_weights=None,        # (Optional) the path of weight file to be saved; not saving weight if None (the default is None). 
            plot_every_num_epoch=30,     # (Optional) plot the intermediate result every few epoches, or not plotting if it is None.            
            dimred='umap'                # (Optional) the name of dimension reduction algorithms, can be 'umap', 'pca' and 'tsne'. Default is 'umap'. Only used if 'plot_every_num_epoch' is not None. 
            #**kwargs                    # (Optional ) extra key-value arguments for calling the dimension reduction algorithms.   
            )
# Out:
# Warmup:5
# Start of epoch 0
# 16/16 [==============================] - 2s 98ms/step - loss_neg_E_nb: 76.6282 - loss_neg_E_pz: 16.5449 - loss_E_qzx   : -7.6445 - loss_total: 8.8770
#  Training loss over epoch: 8.928563117980957
#  70.756577,  16.573067, -7.644501
# Start of epoch 1
# 16/16 [==============================] - 0s 20ms/step - loss_neg_E_nb: 82.1340 - loss_neg_E_pz: 16.3012 - loss_E_qzx   : -7.6445 - loss_total: 8.9435
#  Training loss over epoch: 8.885948181152344
#  71.807899,  16.530451, -7.644501
# Start of epoch 2
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 67.9100 - loss_neg_E_pz: 16.7979 - loss_E_qzx   : -7.6445 - loss_total: 8.9000
#  Training loss over epoch: 8.904991149902344
#  70.398285,  16.549494, -7.644501
# Start of epoch 3
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 67.7321 - loss_neg_E_pz: 16.5293 - loss_E_qzx   : -7.6445 - loss_total: 8.6783
#  Training loss over epoch: 8.703558921813965
#  69.800713,  16.348061, -7.644501
# Start of epoch 4
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 65.9053 - loss_neg_E_pz: 15.6978 - loss_E_qzx   : -7.6445 - loss_total: 8.6171
#  Training loss over epoch: 8.61252498626709
#  69.619797,  16.257027, -7.644501
# Start of epoch 5
# 16/16 [==============================] - 0s 24ms/step - loss_neg_E_nb: 70.5766 - loss_neg_E_pz: 15.3226 - loss_E_qzx   : -7.7170 - loss_total: 87.7325
#  Training loss over epoch: 86.62138366699219
#  70.301285,  15.850833, -7.690782
# Start of epoch 6
# 16/16 [==============================] - 0s 26ms/step - loss_neg_E_nb: 66.3867 - loss_neg_E_pz: 14.5104 - loss_E_qzx   : -7.8380 - loss_total: 83.1322
#  Training loss over epoch: 83.19163513183594
#  69.748512,  14.531753, -7.810196
# Start of epoch 7
# 16/16 [==============================] - 0s 21ms/step - loss_neg_E_nb: 87.0922 - loss_neg_E_pz: 13.9591 - loss_E_qzx   : -7.9454 - loss_total: 81.7537
#  Training loss over epoch: 82.50093078613281
#  70.420418,  13.961384, -7.921124
# Start of epoch 8
# 16/16 [==============================] - 0s 24ms/step - loss_neg_E_nb: 60.6798 - loss_neg_E_pz: 13.3195 - loss_E_qzx   : -8.0407 - loss_total: 81.0603
#  Training loss over epoch: 80.26968383789062
#  69.334404,  13.486765, -8.019119
# Start of epoch 9
# 16/16 [==============================] - 0s 21ms/step - loss_neg_E_nb: 62.9472 - loss_neg_E_pz: 13.9408 - loss_E_qzx   : -8.1273 - loss_total: 80.6776
#  Training loss over epoch: 81.32902526855469
#  70.515648,  13.514327, -8.107636
# Start of epoch 10
# 16/16 [==============================] - 0s 22ms/step - loss_neg_E_nb: 84.8366 - loss_neg_E_pz: 13.1427 - loss_E_qzx   : -8.2079 - loss_total: 79.9961
#  Training loss over epoch: 80.65340423583984
#  70.419823,  13.306008, -8.189218
# Start of epoch 11
# 16/16 [==============================] - 0s 23ms/step - loss_neg_E_nb: 67.9046 - loss_neg_E_pz: 12.9573 - loss_E_qzx   : -8.2812 - loss_total: 79.8331
#  Training loss over epoch: 79.2591323852539
#  69.633949,  13.076921, -8.264331
# Start of epoch 12
# 16/16 [==============================] - 0s 22ms/step - loss_neg_E_nb: 59.4427 - loss_neg_E_pz: 13.3106 - loss_E_qzx   : -8.3543 - loss_total: 77.9452
#  Training loss over epoch: 78.7252426147461
#  69.183815,  13.107882, -8.337175
# Start of epoch 13
# 16/16 [==============================] - 0s 23ms/step - loss_neg_E_nb: 70.4555 - loss_neg_E_pz: 12.9726 - loss_E_qzx   : -8.4234 - loss_total: 80.7855
#  Training loss over epoch: 79.15515899658203
#  69.893974,  13.038102, -8.407505
# Start of epoch 14
# 16/16 [==============================] - 0s 24ms/step - loss_neg_E_nb: 71.7455 - loss_neg_E_pz: 12.9348 - loss_E_qzx   : -8.4893 - loss_total: 79.3632
#  Training loss over epoch: 78.07273864746094
#  69.137787,  12.941634, -8.474154
# Start of epoch 15
# 16/16 [==============================] - 0s 21ms/step - loss_neg_E_nb: 62.3460 - loss_neg_E_pz: 13.1291 - loss_E_qzx   : -8.5548 - loss_total: 79.0745
#  Training loss over epoch: 77.77485656738281
#  69.114006,  12.869848, -8.539423
# Start of epoch 16
# 16/16 [==============================] - 0s 20ms/step - loss_neg_E_nb: 66.6988 - loss_neg_E_pz: 12.7514 - loss_E_qzx   : -8.6193 - loss_total: 76.9700
#  Training loss over epoch: 77.55297088623047
#  69.074318,  12.843637, -8.604313
# Start of epoch 17
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 67.5391 - loss_neg_E_pz: 12.8976 - loss_E_qzx   : -8.6800 - loss_total: 77.2266
#  Training loss over epoch: 77.15308380126953
#  68.891945,  12.796473, -8.665899
# Start of epoch 18
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 70.1407 - loss_neg_E_pz: 12.6713 - loss_E_qzx   : -8.7397 - loss_total: 76.8249
#  Training loss over epoch: 77.30256652832031
#  69.216667,  12.768901, -8.725950
# Start of epoch 19
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 68.8643 - loss_neg_E_pz: 12.8980 - loss_E_qzx   : -8.7947 - loss_total: 78.2441
#  Training loss over epoch: 76.24555206298828
#  68.331146,  12.739077, -8.781875
# Start of epoch 20
# 16/16 [==============================] - 0s 18ms/step - loss_neg_E_nb: 64.9769 - loss_neg_E_pz: 13.0045 - loss_E_qzx   : -8.8501 - loss_total: 77.0855
#  Training loss over epoch: 76.67162322998047
#  68.845757,  12.749857, -8.836925
# Start of epoch 21
# 16/16 [==============================] - 0s 18ms/step - loss_neg_E_nb: 67.4173 - loss_neg_E_pz: 12.5532 - loss_E_qzx   : -8.9055 - loss_total: 75.5869
#  Training loss over epoch: 76.15321350097656
#  68.516434,  12.711147, -8.892760
# Start of epoch 22
# 16/16 [==============================] - 0s 22ms/step - loss_neg_E_nb: 67.4294 - loss_neg_E_pz: 12.5075 - loss_E_qzx   : -8.9606 - loss_total: 75.8354
#  Training loss over epoch: 75.93498229980469
#  68.426537,  12.701879, -8.947653
# Start of epoch 23
# 16/16 [==============================] - 0s 18ms/step - loss_neg_E_nb: 72.0429 - loss_neg_E_pz: 12.6545 - loss_E_qzx   : -9.0146 - loss_total: 76.7830
#  Training loss over epoch: 75.79132843017578
#  68.382263,  12.706543, -9.002010
# Start of epoch 24
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 73.8620 - loss_neg_E_pz: 12.5798 - loss_E_qzx   : -9.0680 - loss_total: 75.6602
#  Training loss over epoch: 75.59700775146484
#  68.391068,  12.658542, -9.055572
# Start of epoch 25
# 16/16 [==============================] - 0s 19ms/step - loss_neg_E_nb: 68.3514 - loss_neg_E_pz: 12.8361 - loss_E_qzx   : -9.1176 - loss_total: 75.9512
# Best Epoch: 19. Best Metric: 76.245552.
# Early stopping.
# Training Done!

# %%
# save model weight
# model.save_model(path_to_file='weight/dentate_train.checkpoint')

# load model weight
model.load_model(path_to_file='weight/dentate_train.checkpoint', # path to the weight file.
                 load_labels=True
                )

# %% [markdown]
# # Inference

# %% [markdown]
# ## Trajectory and Pseudotime

# %%
# initialze inference
model.init_inference(batch_size=32, 
                     L=100,            # L is the number of MC samples
                     dimred='umap',    # 
                     #**kwargs         # extra key-value arguments for dimension reduction algorithms.    
                    ) 
# after initialization, we can access some variables by model.pc_x, model.w, model.w_tilde, etc..
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Sampling.call at 0x7f7ecbbc71e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.

# %%
import networkx as nx
# compute inference score, and get umap embedding
# a plot of clustering result will be displayed
G = model.comp_inference_score(method='modified_map',  # 'mean', 'modified_mean', 'map', and 'modified_map'
                               thres=0.5,              # (Optional) threshold for compute the conditional probablity, only applies to 'mean' and 'modified_mean'
                               no_loop=True            # if no_loop=True, then find the maximum spanning tree
                               )           
# returned G is the score graph
print(np.round(nx.to_numpy_matrix(G), 2))
print(G.edges)
# Out:
# [[0.   0.32 0.   0.23 0.  ]
#  [0.32 0.   0.   0.   0.  ]
#  [0.   0.   0.   0.28 0.16]
#  [0.23 0.   0.28 0.   0.  ]
#  [0.   0.   0.16 0.   0.  ]]
# [(0, 1), (0, 3), (2, 3), (2, 4)]

# %% [markdown]
# Now, the user needs to provide the initial node for the trajectory.

# %%
# Here we identify the 'begin_node_pred' as the one having minimum average 
# distance with the cells in the true begin node.
begin_node_true = model.le.transform([data['root_milestone_id']])[0]
begin_node_pred = int(np.argmin(np.mean((
                        model.z[model.labels[model.selected_cell_subset_id]==begin_node_true,:,np.newaxis] - 
                        model.mu[np.newaxis,:,:])**2, axis=(0,1))))
model.infer_trajectory(init_node=begin_node_pred,  # initial node for computing pseudotime.
                       cutoff=None                 # (Optional) cutoff score for edges (the default is 0.01).
                       )
# Out:
# (<networkx.classes.graph.Graph at 0x7f7ec3904668>,
#  array([[0.        , 0.        , 0.00238022, 0.        , 0.99761975],
#         [0.        , 0.        , 0.        , 0.        , 1.        ],
#         [0.        , 0.        , 0.01363374, 0.        , 0.9863663 ],
#         ...,
#         [0.11208995, 0.88791   , 0.        , 0.        , 0.        ],
#         [0.05029955, 0.9497005 , 0.        , 0.        , 0.        ],
#         [0.15858066, 0.84141934, 0.        , 0.        , 0.        ]],
#        dtype=float32),
#  array([2.38025188e-03, 0.00000000e+00, 1.36337280e-02, ...,
#         3.88790989e+00, 3.94970036e+00, 3.84141922e+00]))

# %% [markdown]
# ## Marker Genes

# %%
model.gene_names
# Out:
# array(['0610007P14Rik', '0610009B22Rik', '0610009L18Rik', ..., 'mt-Nd4',
#        'mt-Nd5', 'mt-Nd6'], dtype='<U14')

# %%
model.plot_marker_gene('Hmgb2')
